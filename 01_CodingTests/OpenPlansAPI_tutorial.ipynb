# %% [markdown]
# <a href="https://colab.research.google.com/github/TopoVague/IBC_dev/blob/main/OpenPlansAPI_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to requests and API's

# %% [markdown]
# ### APIs : What and why
#
# An API (Application Programming interface) is a way for two different applications to communicate. Whilst the term applies to any two programs we are using it to refer to the API of a web service that provides data.
#
# To retrieve data from an API, a request to a remote web server is made.
#
# For example, if you want to build an application which plots stock prices, you would use the API of something like google finance to request the current stock prices.
#
# APIs are useful where:
# * Data is changing quickly, e.g. stock prices
# * The whole dataset is not required, e.g. the tweets of one user
# * Repeated computation is involved, e.g. Spotify API that tells you the genre of a piece of music
#
# #### REST
#
# Most API's you come across will be RESTful, i.e. they provide a REST (REpresentational State Transfer) interface.
#
# REST uses standard HTTP commands which means that getting data from an API is similar to accessing a webpage.
#
# For example, When you type `www.duckduckgo.com` in your browser, your browser is asking the `www.duckduckgo.com` server for a webpage by making a `GET` HTTP (Hypertext Transfer Protocol) request. Making a `GET` request to a RESTful API instead retrieves data (rather than a webpage).
#
# Similarly, while your browser uses `POST` to submit the contents of a form, REST APIs use `POST` to update data.
#
# REST APIs also uses other HTTP commmands such as `PUT` - for creating data - and `DELETE` - for removing data.
#
# HTTP is a text-based protocol (the response is always text) and could return a response in any format - this is typically found in the API documentation - though data is more often than not returned in JSON format.
#
# As they are used to retrieve data `GET` requests are the most commonly used type of request, therefore we will restrict ourselves to `GET` in this tutorial.
#
# #### JSON
#
# JSON (JavaScript Object Notation) is a format for sending data, that is meant to be human readable and easy to parse (It was derived from JavaScript but is language-independent).
#
# It uses attribute-value pairs (e.g. python dictionaries `{"name": "Pizza", "foodRanking": 1}`) and array data-types (e.g. python lists `[1, 2, 3]`)
#
# Example JSON representation :
# ```
# {
#   "firstName": "Donald",
#   "lastName": "Trump",
#   "age": 73,
#   "isAlive": true,
#   "color": "orange",
#   "addresses": [
#       {
#           "streetAddress": "1600 Pennsylvania Avenue NW",
#           "city": "Washington, D.C.",
#           "state": "null",
#           "postalCode": "20500",
#           "country": "US"
#       },
#       {
#           "streetAddress": "721 Fifth Avenue",
#           "city": "NYC",
#           "state": "NY",
#           "postalCode": "10022",
#           "country": "US"
#       }
#   ],
# }
# ```
#
#
# #### Status codes
#
# So we've sent off some mystery `GET` request but how do we know the request was successful?
#
# Servers issue numeric [status codes](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status) in response to HTTP requests that indicate whether a request has been successfully completed.
#
# Some common ones relating to `GET` requests are:
# * `200` - Success
# * `300` - The API is redirecting to a different endpoint
# * `400` - Bad request
# * `401` - Not authenticated
# * `403` - Forbidden
# * `404` - Not found
# * `429` - Too many requests

# %% [markdown]
# We'll learn by example how to use Python to get the data for a REST GET request on the **open-plans** dataset.
#
# We will use the Python library `requests` - https://github.com/psf/requests.

# %% [markdown]
# # Search by Shape

# %%
import requests  # Import the requests library
import json
data = json.dumps(
    {'polygon': [
            {'x': 16700, 'y': 17000},
            {'x': 16700, 'y': 18800},
            {'x': 9500, 'y': 18800},
            {'x': 9500, 'y': 21300},
            {'x': 7900, 'y': 21300},
            {'x': 7900, 'y': 24600},
            {'x': 9500, 'y': 24600},
            {'x': 9500, 'y': 25900},
            {'x': 25400, 'y': 25900},
            {'x': 25300, 'y': 20600},
            {'x': 25400, 'y': 20600},
            {'x': 32400, 'y': 20600},
            {'x': 32400, 'y': 16600},
            {'x': 20700, 'y': 16600},
            {'x': 20700, 'y': 15600},
            {'x': 18200, 'y': 15600},
            {'x': 17700, 'y': 15700},
            {'x': 17400, 'y': 15900},
            {'x': 17100, 'y': 16200},
            {'x': 16800, 'y': 16600},
            {'x': 16700, 'y': 17000},
            ]}
            )
# Query URL
url = ("https://open-plans.herokuapp.com/searchbyshape?number=10")
# Some api's will have nicer syntax like:
# `&time=2010..2012` or `&na_item=B1GQ,D21`
print(url)

response = requests.post(url, data=data,headers={'Content-Type': 'application/json'})

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
projects = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(projects)
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely
# Out:
# https://open-plans.herokuapp.com/searchbyshape?number=10
# Request returned 200 : 'OK'
# {'feature_dimension': 10,
#  'feature_vector': [0.32100706557522035,
#                     0.1257696410652848,
#                     0.02320251482504212,
#                     0.0061418421595699725,
#                     0.0061418421595699725,
#                     5.3502269478920654e-05,
#                     -0.06387769012707227,
#                     -0.09682226079840188,
#                     -0.0038728904319360754,
#                     0.0061418421595699725,
#                     0.3148652234156504,
#                     0.1196277989057148,
#                     0.017060672665472145,
#                     -0.010583104591392166,
#                     -0.13286385338948045,
#                     -0.277804479233732,
#                     -0.3416821693608043,
#                     -0.3826919012814802,
#                     -0.1540139322497661,
#                     -0.0171126591388629,
#                     0.3148652234156504,
#                     0.1196277989057148,
#                     0.017060672665472145,
#                     -0.010583104591392166,
#                     -0.13286385338948045,
#                     -0.39204587529847196,
#                     -0.7881291703183667,
#                     -0.4278164784715725,
#                     -0.1540139322497661,
#                     -0.0171126591388629,
#                     0.013259871441689552,
#                     0.00221106317744519,
#                     0.00221106317744519,
#                     -0.010583104591392166,
#                     -0.13286385338948045,
#                     -0.39204587529847196,
#                     -0.7881291703183667,
#                     -0.4278164784715725,
#                     -0.1540139322497661,
#                     -0.0171126591388629,
#                     -0.0171126591388629,
#                     -0.1540139322497661,
#                     -0.31942071128035876,
#                     -0.3300038158717509,
#                     -0.4522845646698392,
#                     -0.7114665865788307,
#                     -0.838520297804282,
#                     -0.4278164784715725,
#                     -0.1540139322497661,
#                     -0.0171126591388629,
#                     0.010273527623003355,
#                     -0.019164436160696588,
#                     -0.1600531249932766,
#                     -0.4378430869367598,
#                     -0.8525343219911462,
#                     -1.0,
#                     -0.838520297804282,
#                     -0.4278164784715725,
#                     -0.1540139322497661,
#                     -0.0171126591388629,
#                     0.010273527623003355,
#                     -0.019164436160696588,
#                     -0.1600531249932766,
#                     -0.2659341749069442,
#                     -0.14896998040442494,
#                     -0.14272168127804857,
#                     -0.14647519699090303,
#                     -0.15027743201803248,
#                     -0.1540139322497661,
#                     -0.0171126591388629,
#                     0.010273527623003355,
#                     -0.019164436160696588,
#                     -0.1600531249932766,
#                     -0.1255600433620725,
#                     -0.008595848859553246,
#                     0.019314319281890355,
#                     0.03882596864238567,
#                     0.03724218800322914,
#                     0.03569138611790527,
#                     0.03417356298641428,
#                     0.010273527623003355,
#                     -0.019164436160696588,
#                     -0.1600531249932766,
#                     -0.1255600433620725,
#                     -0.008595848859553246,
#                     0.019314319281890355,
#                     0.12548029205687838,
#                     0.3243165631015593,
#                     0.491186860517174,
#                     0.4855114731282396,
#                     0.010273527623003355,
#                     -0.019164436160696588,
#                     -0.09682226079840188,
#                     -0.09682226079840188,
#                     -0.008595848859553246,
#                     0.019314319281890355,
#                     0.12548029205687838,
#                     0.3243165631015593,
#                     0.6158231324159332,
#                     1.0],
#  'original_metrics': {'area': '168465000.0',
#                       'aspect_ratio': '2.38',
#                       'height': '1030.00',
#                       'perimeter': '69008.0',
#                       'width': '2450.00'},
#  'similar_plan_list': [{'created_at': 'Wed, 07 Apr 2021 17:52:59 GMT',
#                         'dimension_factor': '0.00',
#                         'dist_factor': 0.0,
#                         'feature_vector': [0.32100706557522035,
#                                            0.1257696410652848,
#                                            0.02320251482504212,
#                                            0.0061418421595699725,
#                                            0.0061418421595699725,
#                                            5.3502269478920654e-05,
#                                            -0.06387769012707227,
#                                            -0.09682226079840188,
#                                            -0.0038728904319360754,
#                                            0.0061418421595699725,
#                                            0.3148652234156504,
#                                            0.1196277989057148,
#                                            0.017060672665472145,
#                                            -0.010583104591392166,
#                                            -0.13286385338948045,
#                                            -0.277804479233732,
#                                            -0.3416821693608043,
#                                            -0.3826919012814802,
#                                            -0.1540139322497661,
#                                            -0.0171126591388629,
#                                            0.3148652234156504,
#                                            0.1196277989057148,
#                                            0.017060672665472145,
#                                            -0.010583104591392166,
#                                            -0.13286385338948045,
#                                            -0.39204587529847196,
#                                            -0.7881291703183667,
#                                            -0.4278164784715725,
#                                            -0.1540139322497661,
#                                            -0.0171126591388629,
#                                            0.013259871441689552,
#                                            0.00221106317744519,
#                                            0.00221106317744519,
#                                            -0.010583104591392166,
#                                            -0.13286385338948045,
#                                            -0.39204587529847196,
#                                            -0.7881291703183667,
#                                            -0.4278164784715725,
#                                            -0.1540139322497661,
#                                            -0.0171126591388629,
#                                            -0.0171126591388629,
#                                            -0.1540139322497661,
#                                            -0.31942071128035876,
#                                            -0.3300038158717509,
#                                            -0.4522845646698392,
#                                            -0.7114665865788307,
#                                            -0.838520297804282,
#                                            -0.4278164784715725,
#                                            -0.1540139322497661,
#                                            -0.0171126591388629,
#                                            0.010273527623003355,
#                                            -0.019164436160696588,
#                                            -0.1600531249932766,
#                                            -0.4378430869367598,
#                                            -0.8525343219911462,
#                                            -1.0,
#                                            -0.838520297804282,
#                                            -0.4278164784715725,
#                                            -0.1540139322497661,
#                                            -0.0171126591388629,
#                                            0.010273527623003355,
#                                            -0.019164436160696588,
#                                            -0.1600531249932766,
#                                            -0.2659341749069442,
#                                            -0.14896998040442494,
#                                            -0.14272168127804857,
#                                            -0.14647519699090303,
#                                            -0.15027743201803248,
#                                            -0.1540139322497661,
#                                            -0.0171126591388629,
#                                            0.010273527623003355,
#                                            -0.019164436160696588,
#                                            -0.1600531249932766,
#                                            -0.1255600433620725,
#                                            -0.008595848859553246,
#                                            0.019314319281890355,
#                                            0.03882596864238567,
#                                            0.03724218800322914,
#                                            0.03569138611790527,
#                                            0.03417356298641428,
#                                            0.010273527623003355,
#                                            -0.019164436160696588,
#                                            -0.1600531249932766,
#                                            -0.1255600433620725,
#                                            -0.008595848859553246,
#                                            0.019314319281890355,
#                                            0.12548029205687838,
#                                            0.3243165631015593,
#                                            0.491186860517174,
#                                            0.4855114731282396,
#                                            0.010273527623003355,
#                                            -0.019164436160696588,
#                                            -0.09682226079840188,
#                                            -0.09682226079840188,
#                                            -0.008595848859553246,
#                                            0.019314319281890355,
#                                            0.12548029205687838,
#                                            0.3243165631015593,
#                                            0.6158231324159332,
#                                            1.0],
#                         'floor': 1,
#                         'height_mm': 30710.0,
#                         'image_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/60bf1065-1bac-484b-812a-c643229bd6d2.jpeg',
#                         'metrics': {'area': '168465000.0',
#                                     'aspect_ratio': '2.4',
#                                     'height': '1030.00',
#                                     'perimeter': '69008.0',
#                                     'width': '2450.00'},
#                         'mms_per_pixel': 10.0,
#                         'name': 'Haus in Henley-on-Thames, Eng·\nland',
#                         'orientation': None,
#                         'plan_id': 542,
#                         'points': [[16700, 17000],
#                                    [16700, 18800],
#                                    [9500, 18800],
#                                    [9500, 21300],
#                                    [7900, 21300],
#                                    [7900, 24600],
#                                    [9500, 24600],
#                                    [9500, 25900],
#                                    [25400, 25900],
#                                    [25300, 20600],
#                                    [32400, 20600],
#                                    [32400, 16600],
#                                    [20700, 16600],
#                                    [20700, 15600],
#                                    [18200, 15600],
#                                    [17700, 15700],
#                                    [17400, 15900],
#                                    [17100, 16200],
#                                    [16800, 16600],
#                                    [16700, 17000]],
#                         'project_id': 315,
#                         'similarity': 0.0,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/60bf1065-1bac-484b-812a-c643229bd6d2_thumbnail.jpeg',
#                         'type': None,
#                         'updated_at': 'Wed, 07 Apr 2021 17:52:59 GMT',
#                         'width_mm': 35400.0},
#                        {'created_at': 'Wed, 07 Apr 2021 17:52:59 GMT',
#                         'dimension_factor': '0.00',
#                         'dist_factor': 0.778427970848936,
#                         'feature_vector': [0.32100706557522035,
#                                            0.1257696410652848,
#                                            0.02320251482504212,
#                                            0.0061418421595699725,
#                                            0.0061418421595699725,
#                                            5.3502269478920654e-05,
#                                            -0.07617906244409348,
#                                            -0.11546799886888491,
#                                            -0.004618719954755397,
#                                            0.0061418421595699725,
#                                            0.3148652234156504,
#                                            0.1196277989057148,
#                                            0.017060672665472145,
#                                            -0.012621166856788903,
#                                            -0.15845037232538411,
#                                            -0.33130322540930784,
#                                            -0.40748228785340135,
#                                            -0.4563895498815984,
#                                            -0.1836734693877551,
#                                            -0.02040816326530612,
#                                            0.3148652234156504,
#                                            0.1196277989057148,
#                                            0.017060672665472145,
#                                            -0.012621166856788903,
#                                            -0.15845037232538411,
#                                            -0.4675448839164283,
#                                            -0.9399047016299215,
#                                            -0.5102040816326531,
#                                            -0.1836734693877551,
#                                            -0.02040816326530612,
#                                            0.013259871441689552,
#                                            0.00221106317744519,
#                                            0.00221106317744519,
#                                            -0.012621166856788903,
#                                            -0.15845037232538411,
#                                            -0.4675448839164283,
#                                            -0.9399047016299215,
#                                            -0.5102040816326531,
#                                            -0.1836734693877551,
#                                            -0.02040816326530612,
#                                            0.002018891760541312,
#                                            0.03192775228230855,
#                                            -0.0023564897728343857,
#                                            -0.1117283938742808,
#                                            -0.38436560409817616,
#                                            -0.8202681204445206,
#                                            -1.0,
#                                            -0.5102040816326531,
#                                            -0.1836734693877551,
#                                            -0.02040816326530612,
#                                            0.010273527623003355,
#                                            -0.02285506529881252,
#                                            -0.07550385598673441,
#                                            -0.1848757600881808,
#                                            -0.4575129703120762,
#                                            -0.8934154866584205,
#                                            -1.0,
#                                            -0.5102040816326531,
#                                            -0.1836734693877551,
#                                            -0.02040816326530612,
#                                            0.010273527623003355,
#                                            -0.02285506529881252,
#                                            -0.19087567159958527,
#                                            -0.3171469737862154,
#                                            -0.17765816855538522,
#                                            -0.1702065908860814,
#                                            -0.1746829472994959,
#                                            -0.1792174052453391,
#                                            -0.1836734693877551,
#                                            -0.02040816326530612,
#                                            0.010273527623003355,
#                                            -0.02285506529881252,
#                                            -0.19087567159958527,
#                                            -0.14974001665893993,
#                                            -0.010251211428109749,
#                                            0.019314319281890355,
#                                            0.03882596864238567,
#                                            0.03724218800322914,
#                                            0.03569138611790527,
#                                            0.03417356298641428,
#                                            0.010273527623003355,
#                                            -0.02285506529881252,
#                                            -0.19087567159958527,
#                                            -0.14974001665893993,
#                                            -0.010251211428109749,
#                                            0.019314319281890355,
#                                            0.12548029205687838,
#                                            0.3243165631015593,
#                                            0.491186860517174,
#                                            0.4855114731282396,
#                                            0.010273527623003355,
#                                            -0.02285506529881252,
#                                            -0.11546799886888491,
#                                            -0.11546799886888491,
#                                            -0.010251211428109749,
#                                            0.019314319281890355,
#                                            0.12548029205687838,
#                                            0.3243165631015593,
#                                            0.6158231324159332,
#                                            1.0],
#                         'floor': 1,
#                         'height_mm': 30710.0,
#                         'image_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/60bf1065-1bac-484b-812a-c643229bd6d2.jpeg',
#                         'metrics': {'area': '162060000.0',
#                                     'aspect_ratio': '2.4',
#                                     'height': '1030.00',
#                                     'perimeter': '80990.0',
#                                     'width': '2450.00'},
#                         'mms_per_pixel': 10.0,
#                         'name': 'Haus in Henley-on-Thames, Eng·\nland',
#                         'orientation': None,
#                         'plan_id': 542,
#                         'points': [[17200, 16900],
#                                    [17200, 18000],
#                                    [16700, 18800],
#                                    [16700, 17000],
#                                    [16800, 16600],
#                                    [17100, 16200],
#                                    [17400, 15900],
#                                    [17700, 15700],
#                                    [18200, 15600],
#                                    [20700, 15600],
#                                    [20700, 16600],
#                                    [32400, 16600],
#                                    [32400, 20600],
#                                    [25300, 20600],
#                                    [25400, 25900],
#                                    [9500, 25900],
#                                    [9500, 24600],
#                                    [7900, 24600],
#                                    [7900, 21300],
#                                    [9500, 21300],
#                                    [9500, 18800],
#                                    [16700, 18800],
#                                    [17200, 18000],
#                                    [20400, 18000],
#                                    [20400, 15900],
#                                    [18700, 15900],
#                                    [18300, 15900],
#                                    [17700, 16100],
#                                    [17400, 16400],
#                                    [17200, 16900]],
#                         'project_id': 315,
#                         'similarity': 0.000778427970848936,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/60bf1065-1bac-484b-812a-c643229bd6d2_thumbnail.jpeg',
#                         'type': None,
#                         'updated_at': 'Wed, 07 Apr 2021 17:52:59 GMT',
#                         'width_mm': 35400.0},
#                        {'created_at': 'Sat, 16 Oct 2021 14:30:02 GMT',
#                         'dimension_factor': '56896966.89',
#                         'dist_factor': 1.6759221665760227,
#                         'feature_vector': [0.39231441976569803,
#                                            0.03969297040268378,
#                                            -0.014913466019411865,
#                                            -0.03636707326907231,
#                                            -0.019858806923382707,
#                                            -0.01978732460638839,
#                                            -0.019715971172732716,
#                                            -0.019644746622415676,
#                                            -0.019573650955437272,
#                                            -0.007367420795267802,
#                                            0.39231441976569803,
#                                            0.03969297040268378,
#                                            -0.014913466019411865,
#                                            -0.12320470011201008,
#                                            -0.272822468731246,
#                                            -0.2725573454257425,
#                                            -0.27229235100357757,
#                                            -0.2720274854647513,
#                                            -0.09904757632758979,
#                                            -0.007367420795267802,
#                                            0.03458498589071641,
#                                            0.03458498589071641,
#                                            -0.014913466019411865,
#                                            -0.12320470011201008,
#                                            -0.3362722252425748,
#                                            -0.654116041411106,
#                                            -0.5967367605061328,
#                                            -0.2955040228978779,
#                                            -0.09904757632758979,
#                                            -0.007367420795267802,
#                                            -0.01309703637974581,
#                                            -0.07938039138153892,
#                                            -0.09429385740095078,
#                                            -0.202585091493549,
#                                            -0.41565261662411374,
#                                            -0.7334964327926449,
#                                            -0.5946190092986249,
#                                            -0.2940143096352163,
#                                            -0.09818590100977434,
#                                            -0.00713378342229857,
#                                            -0.01309703637974581,
#                                            -0.11787332741771231,
#                                            -0.32742590949364525,
#                                            -0.5629703921611432,
#                                            -0.7760379172917079,
#                                            -1.0,
#                                            -0.5946190092986249,
#                                            -0.2940143096352163,
#                                            -0.09818590100977434,
#                                            -0.00713378342229857,
#                                            -0.01309703637974581,
#                                            -0.11787332741771231,
#                                            -0.32742590949364525,
#                                            -0.6417547826075447,
#                                            -0.7672656923965728,
#                                            -0.5407345060141805,
#                                            -0.4189796106697546,
#                                            -0.2940143096352163,
#                                            -0.09818590100977434,
#                                            -0.00713378342229857,
#                                            -0.01309703637974581,
#                                            -0.11787332741771231,
#                                            -0.2971463522107438,
#                                            -0.5732781572557576,
#                                            -0.4327006277332025,
#                                            -0.20616944135081022,
#                                            -0.08441454600638432,
#                                            -0.06145254795473554,
#                                            -0.038718027834185556,
#                                            -0.00713378342229857,
#                                            -0.0009610317238739139,
#                                            -0.06754025469295458,
#                                            -0.23889576870000176,
#                                            -0.5150275737450155,
#                                            -0.371248079778467,
#                                            -0.1447168933960747,
#                                            -0.022961998051648794,
#                                            0.020835916334883416,
#                                            0.06206859108674738,
#                                            0.1187616456943602,
#                                            -0.0009610317238739139,
#                                            -0.06754025469295458,
#                                            -0.23889576870000176,
#                                            -0.29533948125435755,
#                                            -0.29533948125435755,
#                                            -0.1447168933960747,
#                                            -0.022961998051648794,
#                                            0.020835916334883416,
#                                            0.32657298346417996,
#                                            0.9971715534323426,
#                                            -0.0009610317238739139,
#                                            -0.026263499270524873,
#                                            -0.02626050541768507,
#                                            -0.02625968198859725,
#                                            -0.02625968198859725,
#                                            -0.0262614603964433,
#                                            -0.022727805305363644,
#                                            0.021252410906077514,
#                                            0.3282041359646298,
#                                            1.0],
#                         'floor': 2,
#                         'height_mm': 10270.9,
#                         'image_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/1c84ed86-81b6-46ee-aff0-fac2636b8457.jpeg',
#                         'metrics': {'area': '143492441.0',
#                                     'aspect_ratio': '1.7',
#                                     'height': '1017.60',
#                                     'perimeter': '55260.0',
#                                     'width': '1695.80'},
#                         'mms_per_pixel': 10.0,
#                         'name': 'cubicasa_9639',
#                         'orientation': None,
#                         'plan_id': 6470,
#                         'points': [[15613, 7288],
#                                    [16830, 7280],
#                                    [16830, 7195],
#                                    [16958, 7195],
#                                    [16958, 7068],
#                                    [16830, 7068],
#                                    [16830, 5116],
#                                    [16957, 5116],
#                                    [16957, 4988],
#                                    [16830, 4988],
#                                    [16830, 2951],
#                                    [16957, 2951],
#                                    [16957, 2824],
#                                    [16830, 2824],
#                                    [16830, 371],
#                                    [12095, 371],
#                                    [12095, 0],
#                                    [11748, 0],
#                                    [9452, 0],
#                                    [8026, 0],
#                                    [7916, 0],
#                                    [7297, 0],
#                                    [5648, 0],
#                                    [4682, 0],
#                                    [4682, 2001],
#                                    [3301, 2001],
#                                    [3191, 2001],
#                                    [2574, 2001],
#                                    [1513, 2001],
#                                    [0, 2001],
#                                    [0, 4549],
#                                    [221, 4549],
#                                    [227, 10049],
#                                    [100, 10049],
#                                    [100, 10176],
#                                    [227, 10176],
#                                    [227, 10049],
#                                    [1339, 10049],
#                                    [1339, 10171],
#                                    [1466, 10171],
#                                    [1466, 10049],
#                                    [4684, 10049],
#                                    [4684, 10043],
#                                    [11897, 10043],
#                                    [11897, 8667],
#                                    [12124, 8667],
#                                    [12124, 7288],
#                                    [12997, 7288],
#                                    [14045, 7288]],
#                         'project_id': 5051,
#                         'similarity': 0.0016759221665760228,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/1c84ed86-81b6-46ee-aff0-fac2636b8457_thumbnail.jpeg',
#                         'type': None,
#                         'updated_at': 'Sat, 16 Oct 2021 14:30:02 GMT',
#                         'width_mm': 17050.701},
#                        {'created_at': 'Sat, 16 Oct 2021 13:51:22 GMT',
#                         'dimension_factor': '671933691.38',
#                         'dist_factor': 1.6779266093320153,
#                         'feature_vector': [0.22749529204493596,
#                                            0.11719646230541324,
#                                            0.04314540139251571,
#                                            0.005342109306243382,
#                                            -0.0015220807943580666,
#                                            -0.01010527683970218,
#                                            -0.014917145499762134,
#                                            -0.007008633192392385,
#                                            0.002481836546916094,
#                                            0.11520517662291459,
#                                            0.010464762003625944,
#                                            -0.00041334933291552526,
#                                            -0.011024464059503452,
#                                            -0.03597239547607878,
#                                            -0.07525714358264136,
#                                            -0.11820941508818235,
#                                            -0.13559209556300303,
#                                            -0.10069758346219639,
#                                            -0.027952491739323525,
#                                            0.007489112614342755,
#                                            -0.010170618364408988,
#                                            -0.06551627266766734,
#                                            -0.11602738031594768,
#                                            -0.1808753046542153,
#                                            -0.2600600456824702,
#                                            -0.3446945309361365,
#                                            -0.3773901351201244,
#                                            -0.2926703654980485,
#                                            -0.10634408469472256,
#                                            -0.003969310172895496,
#                                            -0.0008345013803965333,
#                                            -0.09570161925366169,
#                                            -0.33207373596176143,
#                                            -0.43682165322172145,
#                                            -0.5559063871716687,
#                                            -0.684794820054207,
#                                            -0.7403112641711342,
#                                            -0.48858527614961755,
#                                            -0.17600794778641854,
#                                            -0.01764139364867219,
#                                            0.0046909319014796285,
#                                            -0.05635640356398909,
#                                            -0.2681832079463794,
#                                            -0.6373357833659145,
#                                            -0.9627961680502272,
#                                            -1.0,
#                                            -0.7775296625603381,
#                                            -0.4805050789317058,
#                                            -0.18216179428100432,
#                                            -0.01870583939682228,
#                                            0.03345755802232976,
#                                            -0.027368173696673163,
#                                            -0.19882889355104683,
#                                            -0.5276153844425631,
#                                            -0.7229247066123361,
#                                            -0.5844504615388211,
#                                            -0.4378204310664198,
#                                            -0.26481429662507444,
#                                            -0.09651234483024462,
#                                            -0.004013323631807432,
#                                            0.08840974792259444,
#                                            -0.008736929651713167,
#                                            -0.13983156497807053,
#                                            -0.42825197134156984,
#                                            -0.3780982931731522,
#                                            -0.27998997043167306,
#                                            -0.1916628708510088,
#                                            -0.0954105902590066,
#                                            -0.0192388813737689,
#                                            0.013054336765244102,
#                                            0.16954750160226778,
#                                            -0.000462671429110793,
#                                            -0.09119122222745087,
#                                            -0.2165044224844126,
#                                            -0.14405377293167615,
#                                            -0.08631137252221749,
#                                            -0.042647948069370986,
#                                            -0.008404057964873757,
#                                            0.00816941929927313,
#                                            0.14552209398726318,
#                                            0.27687081906136163,
#                                            0.0064355315105788765,
#                                            -0.05290786529918772,
#                                            -0.052875873108598544,
#                                            -0.020791145887891025,
#                                            -0.0034146678104518976,
#                                            0.001869700810289389,
#                                            0.04368791374782186,
#                                            0.17621815325981263,
#                                            0.46383720099638404,
#                                            0.41037970029985926,
#                                            0.03788685478159648,
#                                            -0.006456270962442595,
#                                            7.386915554066733e-05,
#                                            0.021011211976746692,
#                                            0.07913541617157827,
#                                            0.1744464817400478,
#                                            0.3209888484944447,
#                                            0.5787611846430161,
#                                            1.0],
#                         'floor': 1,
#                         'height_mm': 8231.101,
#                         'image_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/89e2e1ef-a457-40a3-9cb2-32d40b6eb196.jpeg',
#                         'metrics': {'area': '188201.0',
#                                     'aspect_ratio': '0.8',
#                                     'height': '56.60',
#                                     'perimeter': '1658.5',
#                                     'width': '47.50'},
#                         'mms_per_pixel': 10.0,
#                         'name': 'cubicasa_6094',
#                         'orientation': None,
#                         'plan_id': 5341,
#                         'points': [[8317, 711],
#                                    [8313, 722],
#                                    [8303, 750],
#                                    [8285, 789],
#                                    [8273, 810],
#                                    [8259, 831],
#                                    [8242, 852],
#                                    [8223, 870],
#                                    [8202, 887],
#                                    [8177, 900],
#                                    [8151, 910],
#                                    [8121, 914],
#                                    [8105, 914],
#                                    [8088, 913],
#                                    [8071, 910],
#                                    [8053, 905],
#                                    [8034, 899],
#                                    [8018, 891],
#                                    [8002, 883],
#                                    [7989, 874],
#                                    [7966, 853],
#                                    [7948, 830],
#                                    [7935, 805],
#                                    [7925, 779],
#                                    [7920, 753],
#                                    [7917, 726],
#                                    [7917, 701],
#                                    [7918, 676],
#                                    [7925, 634],
#                                    [7932, 605],
#                                    [7935, 595],
#                                    [8010, 348],
#                                    [8392, 465]],
#                         'project_id': 4149,
#                         'similarity': 0.0016779266093320153,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/89e2e1ef-a457-40a3-9cb2-32d40b6eb196_thumbnail.jpeg',
#                         'type': None,
#                         'updated_at': 'Sat, 16 Oct 2021 13:51:22 GMT',
#                         'width_mm': 13615.1},
#                        {'created_at': 'Sat, 16 Oct 2021 13:56:40 GMT',
#                         'dimension_factor': '672671126.16',
#                         'dist_factor': 1.6810199844132896,
#                         'feature_vector': [0.15083512903309593,
#                                            0.07163100993195627,
#                                            0.02158090812946297,
#                                            0.0006848236256128019,
#                                            -0.0028625482536200567,
#                                            -0.010806873627225691,
#                                            -0.013372602038720174,
#                                            -0.0050098935079029945,
#                                            0.005633025639060585,
#                                            0.14659266464218845,
#                                            -9.993602030092134e-05,
#                                            -0.006131724134224869,
#                                            -0.02149562165390094,
#                                            -0.04619162857933031,
#                                            -0.08021974491051265,
#                                            -0.11514388085146955,
#                                            -0.12368703737965041,
#                                            -0.08788220520984552,
#                                            -0.022463421043765888,
#                                            0.01222006477009446,
#                                            -0.007737889611357652,
#                                            -0.09488460193140237,
#                                            -0.1416332774211332,
#                                            -0.19771406231661842,
#                                            -0.26312695661785657,
#                                            -0.33028127758692233,
#                                            -0.3454422943122843,
#                                            -0.26089007932007624,
#                                            -0.09561264598816926,
#                                            -0.00303190274733156,
#                                            -0.0009454408278161884,
#                                            -0.09553014820255933,
#                                            -0.34505169899482074,
#                                            -0.4547865111043841,
#                                            -0.5515841833756806,
#                                            -0.6526643237618472,
#                                            -0.6786383728366393,
#                                            -0.45539775741058175,
#                                            -0.16281864068283558,
#                                            -0.015411275674496025,
#                                            0.002188775736770567,
#                                            -0.06343460007747723,
#                                            -0.281105423330981,
#                                            -0.6537130900019733,
#                                            -0.945591425183935,
#                                            -1.0,
#                                            -0.7966477547711194,
#                                            -0.4918249877017059,
#                                            -0.17961716963320212,
#                                            -0.019699821680829677,
#                                            0.02187908948348423,
#                                            -0.03788668014961111,
#                                            -0.22370677586435722,
#                                            -0.5644637149965939,
#                                            -0.7060669895524994,
#                                            -0.5942677609903038,
#                                            -0.4613243311118975,
#                                            -0.2882623585532793,
#                                            -0.11083422111119785,
#                                            -0.0065221265545562625,
#                                            0.06202454980285315,
#                                            -0.018886388418960936,
#                                            -0.17285575659494196,
#                                            -0.46261848182429166,
#                                            -0.37304042079207056,
#                                            -0.293092381437925,
#                                            -0.21144530574391532,
#                                            -0.11513537148506461,
#                                            -0.029464925884083074,
#                                            0.004402423943869875,
#                                            0.12262515669487731,
#                                            -0.006433724885526728,
#                                            -0.12855236552275762,
#                                            -0.20308817663224585,
#                                            -0.14536130480807366,
#                                            -0.09726445466197842,
#                                            -0.05643161284469071,
#                                            -0.017041775620931666,
#                                            0.0006463982570465893,
#                                            0.12024637747685112,
#                                            0.20368091015955675,
#                                            -0.0005286895493084858,
#                                            -0.08441102851081032,
#                                            -0.048905324216612776,
#                                            -0.023029641600491455,
#                                            -0.006783980662444672,
#                                            -0.00012868249140408062,
#                                            0.02319944729315436,
#                                            0.14296116705322495,
#                                            0.43798218278723067,
#                                            0.3051918101968914,
# ...
#                                            0.008958867190384889,
#                                            0.3090194634403558,
#                                            0.0491149697964172,
#                                            -0.010464324892305227,
#                                            -0.16495213720218307,
#                                            -0.5084727247173338,
#                                            -1.0,
#                                            -0.6448280438686265,
#                                            -0.3437368098940355,
#                                            -0.12244033244124178,
#                                            -0.00653998421784916,
#                                            0.23722459420020509,
#                                            0.024431270064461177,
#                                            -0.02611513381568593,
#                                            -0.2163477944932651,
#                                            -0.5908416719278008,
#                                            -0.9590286675395187,
#                                            -0.7995619214527329,
#                                            -0.579327122233119,
#                                            -0.20509061190045644,
#                                            -0.02091008644062046,
#                                            0.13336141569647075,
#                                            0.0020874811218632248,
#                                            -0.061814179542486296,
#                                            -0.29023620174267345,
#                                            -0.5964521483201356,
#                                            -0.4528138095977983,
#                                            -0.3332810240206519,
#                                            -0.26806411240259015,
#                                            -0.13099672695721484,
#                                            -0.007918505869796585,
#                                            0.04184137983943871,
#                                            -0.007168792385358503,
#                                            -0.12908621562061515,
#                                            -0.3933040666750568,
#                                            -0.23241169169451953,
#                                            -0.13434331642696984,
#                                            -0.07193176417063135,
#                                            -0.04021541295322272,
#                                            -0.011445393726882445,
#                                            0.008412904253472483,
#                                            0.00024074681772993782,
#                                            -0.05793989542333783,
#                                            -0.2612367545906749,
#                                            -0.118274938847778,
#                                            -0.03871494800007072,
#                                            -0.003617188027143212,
#                                            0.0017684213654575239,
#                                            0.016510156918391895,
#                                            0.04526504108117506,
#                                            0.11768940834589595,
#                                            -0.0008641247126298577,
#                                            -0.053811864859859275,
#                                            -0.0730695745287325,
#                                            -0.007222779004989261,
#                                            0.009514089929441638,
#                                            0.06619375610924785,
#                                            0.1440001310796483,
#                                            0.22832620776362253,
#                                            0.29765286673347036,
#                                            0.44812877728645467,
#                                            0.05581956959829173,
#                                            0.00017328474928817646,
#                                            -0.0016099819143720758,
#                                            0.03655511913920027,
#                                            0.15617326641637172,
#                                            0.3266278572496635,
#                                            0.5139375542305477,
#                                            0.680925686664636,
#                                            0.7963755219947859,
#                                            1.0],
#                         'floor': 1,
#                         'height_mm': 13497.4,
#                         'image_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/c54d1854-a470-4eaf-8070-b4543c47d73e.jpeg',
#                         'metrics': {'area': '5335.5',
#                                     'aspect_ratio': '1.1',
#                                     'height': '9.40',
#                                     'perimeter': '298.3',
#                                     'width': '9.90'},
#                         'mms_per_pixel': 10.0,
#                         'name': 'cubicasa_9722',
#                         'orientation': None,
#                         'plan_id': 6498,
#                         'points': [[15927, 2795],
#                                    [15917, 2802],
#                                    [15906, 2808],
#                                    [15893, 2813],
#                                    [15879, 2815],
#                                    [15868, 2816],
#                                    [15859, 2818],
#                                    [15852, 2824],
#                                    [15847, 2833],
#                                    [15846, 2844],
#                                    [15848, 2851],
#                                    [15851, 2858],
#                                    [15861, 2871],
#                                    [15860, 2870],
#                                    [15871, 2881],
#                                    [15878, 2886],
#                                    [15884, 2888],
#                                    [15895, 2889],
#                                    [15905, 2885],
#                                    [15912, 2879],
#                                    [15915, 2870],
#                                    [15917, 2860],
#                                    [15922, 2846],
#                                    [15929, 2833],
#                                    [15936, 2823],
#                                    [15945, 2815]],
#                         'project_id': 5075,
#                         'similarity': 0.0018065993225351582,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/c54d1854-a470-4eaf-8070-b4543c47d73e_thumbnail.jpeg',
#                         'type': None,
#                         'updated_at': 'Sat, 16 Oct 2021 14:31:00 GMT',
#                         'width_mm': 18389.105},
#                        {'created_at': 'Sat, 16 Oct 2021 14:09:37 GMT',
#                         'dimension_factor': '699595358.92',
#                         'dist_factor': 1.8294584632121318,
#                         'feature_vector': [0.6291323252988488,
#                                            0.2282167808533305,
#                                            0.044647913082103634,
#                                            -0.00038006006874415044,
#                                            -0.02001724061150971,
#                                            -0.021793406969798843,
#                                            -0.0013792146135420476,
#                                            0.024109181024699975,
#                                            0.14019284747087285,
#                                            0.3697862470762301,
#                                            0.4853372533561922,
#                                            0.12649848670294664,
#                                            0.00021523851567705816,
#                                            -0.06690384634264918,
#                                            -0.19958503025143698,
#                                            -0.20888085114554503,
#                                            -0.09417336831043388,
#                                            -0.013150229603141774,
#                                            0.010141571719246088,
#                                            0.1243008201013364,
#                                            0.4153185096940725,
#                                            0.08567175266758781,
#                                            -0.0026827134571152877,
#                                            -0.1298113740935521,
#                                            -0.44471520093089245,
#                                            -0.559852148420889,
#                                            -0.3110610199008187,
#                                            -0.12721925845019896,
#                                            -0.01843942782364471,
#                                            0.009915984054902122,
#                                            0.35664299736843913,
#                                            0.06336249836616287,
#                                            -0.006761466564904548,
#                                            -0.1484635463105083,
#                                            -0.4785808265044213,
#                                            -1.0,
#                                            -0.6426868893191258,
#                                            -0.33731855014070566,
#                                            -0.1194063706089314,
#                                            -0.006271814957043916,
#                                            0.2662813873167846,
#                                            0.03186010820232329,
#                                            -0.02144717630849831,
#                                            -0.2019974115957373,
#                                            -0.5661567710246675,
#                                            -0.9740241442533679,
#                                            -0.8208051423970845,
#                                            -0.5847180494007743,
#                                            -0.20760497214674437,
#                                            -0.02149308015891947,
#                                            0.14828279730588378,
#                                            0.003124509402597386,
#                                            -0.05744383255511757,
#                                            -0.2791773243850016,
#                                            -0.6027889467502491,
#                                            -0.4646874340657891,
#                                            -0.34936126470860523,
#                                            -0.2880230126128317,
#                                            -0.14302615136344296,
#                                            -0.00973732611686652,
#                                            0.04457548616088199,
#                                            -0.0068937993714127815,
#                                            -0.125721009943553,
#                                            -0.393483209861131,
#                                            -0.2369574379496986,
#                                            -0.14170188501369047,
#                                            -0.08012080233483493,
#                                            -0.0490245881263045,
#                                            -0.017107008524876673,
#                                            0.005663626314034846,
#                                            9.094739593931067e-05,
#                                            -0.05880094161433841,
#                                            -0.2607980946109392,
#                                            -0.11817599361650123,
#                                            -0.04061844926592166,
#                                            -0.005067497097077444,
#                                            0.000640192568388658,
#                                            0.011450436085094842,
#                                            0.036955409916571015,
#                                            0.10760309527349003,
#                                            -0.0005048828193365369,
#                                            -0.052634792277225576,
#                                            -0.07021887703788625,
#                                            -0.007019204003891272,
#                                            0.00910854554565516,
#                                            0.06535106741223089,
#                                            0.13938949009734952,
#                                            0.21759811960207318,
#                                            0.285149479884444,
#                                            0.433792241313069,
#                                            0.06036050128006733,
#                                            9.433507404885178e-05,
#                                            -0.0010568589446167912,
#                                            0.040135952082461776,
#                                            0.16560051706257198,
#                                            0.3374174415466344,
#                                            0.5204122051629276,
#                                            0.682179463226396,
#                                            0.7880015918537813,
#                                            1.0],
#                         'floor': 1,
#                         'height_mm': 10214.0,
#                         'image_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/efa84b3e-0f25-4c95-8078-ab0bffe246ff.jpeg',
#                         'metrics': {'area': '5351.5',
#                                     'aspect_ratio': '1.0',
#                                     'height': '9.50',
#                                     'perimeter': '297.5',
#                                     'width': '9.80'},
#                         'mms_per_pixel': 10.0,
#                         'name': 'cubicasa_7949',
#                         'orientation': None,
#                         'plan_id': 5879,
#                         'points': [[10702, 721],
#                                    [10693, 729],
#                                    [10682, 735],
#                                    [10669, 740],
#                                    [10655, 743],
#                                    [10644, 744],
#                                    [10635, 746],
#                                    [10628, 752],
#                                    [10623, 761],
#                                    [10622, 773],
#                                    [10624, 779],
#                                    [10627, 786],
#                                    [10637, 799],
#                                    [10637, 798],
#                                    [10648, 809],
#                                    [10655, 813],
#                                    [10661, 816],
#                                    [10673, 816],
#                                    [10682, 812],
#                                    [10689, 806],
#                                    [10692, 797],
#                                    [10694, 787],
#                                    [10698, 773],
#                                    [10705, 760],
#                                    [10712, 750],
#                                    [10720, 741]],
#                         'project_id': 4585,
#                         'similarity': 0.0018294584632121318,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/efa84b3e-0f25-4c95-8078-ab0bffe246ff_thumbnail.jpeg',
#                         'type': None,
#                         'updated_at': 'Sat, 16 Oct 2021 14:09:37 GMT',
#                         'width_mm': 17084.645}],
#  'succeeded': 1}

# %% [markdown]
# # Projects

# %%
import requests  # Import the requests library

# Query URL
url = ("https://open-plans.herokuapp.com/project/fetch/recent?number=4&page=1"
       )
# Some api's will have nicer syntax like:
# `&time=2010..2012` or `&na_item=B1GQ,D21`
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
projects = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(projects)
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely
# Out:
# https://open-plans.herokuapp.com/project/fetch/recent?number=4&page=1
# Request returned 200 : 'OK'
# {'projects': [{'account_name': 'test',
#                'architects': 'A. Komter, Amsterdam',
#                'civil_engineers': None,
#                'clients': None,
#                'created_at': 'Wed, 07 Apr 2021 18:04:48 GMT',
#                'created_by': 8,
#                'description': '3 Wohnräume, davon zwei\n'
#                               'durch Schiebewand verbunden; 4 Schlafzimmer '
#                               'und\n'
#                               'Mädchenkammer (im Erdgeschoß). Der Plan zeigt '
#                               'die Möglichkeit, auch im strengen Rahmen eines '
#                               'Skelettbaues (hier Rohrstützen und '
#                               'Leichtprofile) ziemlich ungebunden vorzugehen, '
#                               'teilweise mit Hilfe gebogener Rabitzwände. Die '
#                               'Schiebewand zwischen\n'
#                               'Wohn- und Eßzimmer läuft S-förmig in einen '
#                               'eigenen Wandschrank.',
#                'floor_area': None,
#                'floors': None,
#                'geolocation': None,
#                'height': None,
#                'id': 557,
#                'name': 'Haus in Hattem, HoJiand',
#                'plans': [{'height_mm': 19920.0,
#                           'id': 964,
#                           'mms_per_pixel': 10.0,
#                           'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/2359608c-21b2-4e19-8a61-a762787a5a67_thumbnail.jpeg',
#                           'width_mm': 16760.0},
#                          {'height_mm': 19920.0,
#                           'id': 963,
#                           'mms_per_pixel': 10.0,
#                           'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/01a5dcad-4b5f-4619-a3ae-d7a35444b177_thumbnail.jpeg',
#                           'width_mm': 16760.0}],
#                'source': 'Völckers, Otto, ed. Das Grundrisswerk, 1400 '
#                          'Grundrisse ausgeführter Bauten jeder Art, mit '
#                          'Erläuterungen, Schnitten und Schaubildern. J. '
#                          'Hoffmann, 1941., also published in Bouwkundig '
#                          'Weekblad Architectura 1937/50',
#                'year_of_completion': None},
#               {'account_name': 'test',
#                'architects': 'Architekt : Franz Schuster, Wien',
#                'civil_engineers': None,
#                'clients': None,
#                'created_at': 'Wed, 07 Apr 2021 18:04:46 GMT',
#                'created_by': 8,
#                'description': 'Eßküche, Wohnzimmer und Spül- und Waschküche '
#                               '(mit Badewanne) nebeneinander. Oben 5 Betten.',
#                'floor_area': None,
#                'floors': None,
#                'geolocation': None,
#                'height': None,
#                'id': 556,
#                'name': 'Reihenhaustyp der Siedlung Am Wasserturm in Wien',
#                'plans': [{'height_mm': 12740.0,
#                           'id': 962,
#                           'mms_per_pixel': 10.0,
#                           'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/bc2aed16-dcc6-439d-b082-b6ede14216aa_thumbnail.jpeg',
#                           'width_mm': 6220.0},
#                          {'height_mm': 12740.0,
#                           'id': 961,
#                           'mms_per_pixel': 10.0,
#                           'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/0a579176-7a59-4eba-bed3-642d712d25c7_thumbnail.jpeg',
#                           'width_mm': 6220.0}],
#                'source': 'Völckers, Otto, ed. Das Grundrisswerk, 1400 '
#                          'Grundrisse ausgeführter Bauten jeder Art, mit '
#                          'Erläuterungen, Schnitten und Schaubildern. J. '
#                          'Hoffmann, 1941., also published in Aus: F. Schuster, '
#                          'Ein eingerichtetes Siedlungshaus, Frankfurt am\n'
#                          'Main, o. J.',
#                'year_of_completion': None},
#               {'account_name': 'test',
#                'architects': 'Paul A. R. Frank, Harnburg',
#                'civil_engineers': None,
#                'clients': None,
#                'created_at': 'Wed, 07 Apr 2021 18:04:44 GMT',
#                'created_by': 8,
#                'description': '',
#                'floor_area': None,
#                'floors': None,
#                'geolocation': None,
#                'height': None,
#                'id': 555,
#                'name': 'Duisbergsiedlung in Hamburg',
#                'plans': [{'height_mm': 11820.0,
#                           'id': 960,
#                           'mms_per_pixel': 10.0,
#                           'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/c275ce4c-996f-4476-bf33-7a64a0387f36_thumbnail.jpeg',
#                           'width_mm': 6220.0}],
#                'source': 'Völckers, Otto, ed. Das Grundrisswerk, 1400 '
#                          'Grundrisse ausgeführter Bauten jeder Art, mit '
#                          'Erläuterungen, Schnitten und Schaubildern. J. '
#                          'Hoffmann, 1941., also published in Nach Hamburg und '
#                          'seine Bauten',
#                'year_of_completion': None},
#               {'account_name': 'test',
#                'architects': 'Carl Hörvik, Äppelviken',
#                'civil_engineers': None,
#                'clients': None,
#                'created_at': 'Wed, 07 Apr 2021 18:04:42 GMT',
#                'created_by': 8,
#                'description': 'Anlage sehr ähnlich der von 185-187, aber auf '
#                               'kleinerer Fläche zwischen Haupt und Nebenräumen '
#                               'hälftig aufgeteilt.',
#                'floor_area': None,
#                'floors': None,
#                'geolocation': None,
#                'height': None,
#                'id': 554,
#                'name': 'Kleinhaus in Stockholm-Äppelviken',
#                'plans': [{'height_mm': 8250.0,
#                           'id': 958,
#                           'mms_per_pixel': 10.0,
#                           'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/c362e245-173e-4d7f-b0e5-e9c2a63032e8_thumbnail.jpeg',
#                           'width_mm': 8240.0},
#                          {'height_mm': 8250.0,
#                           'id': 959,
#                           'mms_per_pixel': 10.0,
#                           'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/9cc3e60a-3ae1-4716-ac8b-f9eb645f6a31_thumbnail.jpeg',
#                           'width_mm': 8240.0}],
#                'source': 'Völckers, Otto, ed. Das Grundrisswerk, 1400 '
#                          'Grundrisse ausgeführter Bauten jeder Art, mit '
#                          'Erläuterungen, Schnitten und Schaubildern. J. '
#                          'Hoffmann, 1941., also published in Schweizerische '
#                          'Bauzeitung 1930 Band 96/24',
#                'year_of_completion': None}],
#  'succeeded': 1}

# %% [markdown]
# # Project

# %%
import requests  # Import the requests library

# Query URL
url = ("https://open-plans.herokuapp.com/project/fetch/315"
       )
print(url)

response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
project = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(project)
# NOTE: Could use print(response.json()) but this wouldn't be formatted nicely
# Out:
# https://open-plans.herokuapp.com/project/fetch/315
# Request returned 200 : 'OK'
# {'project': {'account_name': 'test',
#              'architects': 'Christopher Nicholson',
#              'civil_engineers': None,
#              'clients': None,
#              'created_at': 'Wed, 07 Apr 2021 17:52:59 GMT',
#              'created_by': 8,
#              'description': '2 Wohnräume, durch Schiebewand zu einem sehr '
#                             'großen Hauptraum zu verbinden, 4 '
#                             'Hauptschlafräume, Gast und Mädchenzimmer und sehr '
#                             'reichliche Zubehörräume, besonders im Erdgeschoß. '
#                             'Die Obergeschoßterrasse dient auch als '
#                             'Schlafveranda. Zu beachten die geschmeidige '
#                             'Einführung des Haupteingangs· und die damit '
#                             'zusammenhängende Form des Hauptraums.\n'
#                             '\n'
#                             '1 Eingangshalle, 2 Wohnraum, 3 Eßraum, 4 '
#                             'Gedeckte\n'
#                             'Terrasse, 5 Kleiderablage mit WC, 6 An·\n'
#                             'richte, 7 Küche, 8 Leute-Wohn- und -Eßzimmer,\n'
#                             '9-10 Speisekammern, 11 Küchcneingang, 12 Zimmer\n'
#                             'des Chauffeurs mit Brausebad und WC.,\n'
#                             '13 Wagenraum, 14-17 Wohn- und Schlafzimmer,\n'
#                             '18 Kleines Arbeitszimmer, 19 Gastzimmer, 20 '
#                             'Mädchenzimmer',
#              'floor_area': None,
#              'floors': None,
#              'geolocation': None,
#              'height': None,
#              'id': 315,
#              'name': 'Haus in Henley-on-Thames, Eng·\nland',
#              'plans': [{'height_mm': 30710.0,
#                         'id': 541,
#                         'mms_per_pixel': 10.0,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/042d8933-2efe-4854-90a6-64387f9aede1_thumbnail.jpeg',
#                         'width_mm': 35400.0},
#                        {'height_mm': 30710.0,
#                         'id': 542,
#                         'mms_per_pixel': 10.0,
#                         'thumbnail_path': 'https://open-plans.s3.eu-central-1.amazonaws.com/plan/60bf1065-1bac-484b-812a-c643229bd6d2_thumbnail.jpeg',
#                         'width_mm': 35400.0}],
#              'source': 'Völckers, Otto, ed. Das Grundrisswerk, 1400 Grundrisse '
#                        'ausgeführter Bauten jeder Art, mit Erläuterungen, '
#                        'Schnitten und Schaubildern. J. Hoffmann, 1941., also '
#                        'published in The Architectural Review 1938, Juni.',
#              'year_of_completion': None},
#  'succeeded': 1}

# %% [markdown]
# # Plan

# %%
import requests  # Import the requests library
url = ("https://open-plans.herokuapp.com/plan/fetch/506" )
print(url)
response = requests.get(url)
print(f"Request returned {response.status_code} : '{response.reason}'")
jsonresponse = response.json()  # Parse `response.text` into JSON
plan=jsonresponse["plan"]
img=jsonresponse["plan"]["image_path"]
poly =""
polygons=jsonresponse["plan"]["polygons"]
for cpoly in polygons:
    if len(cpoly["points"])>2:
        poly=cpoly["points"]
        break
coord = []
for point in poly:
    coord.append([point["x"],point["y"]])
xs, ys = zip(*coord) #create lists of x and y values

import matplotlib.pyplot as plt
plt.figure()
plt.plot(xs,ys)
plt.show() # if you need.

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(plan)
# Out:
# https://open-plans.herokuapp.com/plan/fetch/506
# Request returned 200 : 'OK'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-eeca2311c140> in <module>()
#       5 print(f"Request returned {response.status_code} : '{response.reason}'")
#       6 jsonresponse = response.json()  # Parse `response.text` into JSON
# ----> 7 plan=jsonresponse["plan"]
#       8 img=jsonresponse["plan"]["image_path"]
#       9 poly =""
#
# KeyError: 'plan'

# %% [markdown]
# # Plans

# %%
import requests  # Import the requests library

# Query URL
url = ("https://open-plans.herokuapp.com/plan/fetch/recent?number=20&page=5")
response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
projects = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(projects)

# %%
import requests  # Import the requests library
url = ("https://open-plans.herokuapp.com/polygon_tag/all" )
print(url)
response = requests.get(url)
print(f"Request returned {response.status_code} : '{response.reason}'")
types = response.json()  # Parse `response.text` into JSON
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(types)

# %% [markdown]
# # Signup

# %%
import requests  # Import the requests library
import json
url = ("https://open-plans.herokuapp.com/auth/signup" )
data = json.dumps({'email': 'test@gmail.com', 'password': 'testtest', 'name': 'test'})
response = requests.post(url, data=data, headers={'Content-Type': 'application/json'})
types = response.json()  # Parse `response.text` into JSON
import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(types)

# %% [markdown]
# # Polygon

# %%
import requests  # Import the requests library

# Query URL
url = ("https://open-plans.herokuapp.com/polygon/fetch/recent?number=20&page=5")
response = requests.get(url)  # Make a GET request to the URL

# Print status code (and associated text)
print(f"Request returned {response.status_code} : '{response.reason}'")

# Print data returned (parsing as JSON)
projects = response.json()  # Parse `response.text` into JSON

import pprint
pp = pprint.PrettyPrinter(indent=1)
pp.pprint(projects)
